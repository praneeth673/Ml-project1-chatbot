# %% [markdown]
# <a href="https://colab.research.google.com/github/praneeth673/Ml-project1-chatbot/blob/main/vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
from datetime import datetime

def greet_and_introduce():
    # declare that list of responses
    responses= ["Hi,I am vision.\nNice to see you.\nI can help you do some calulations and you can know information about Engineering collages",
    "Hi there,its wonderful to see you.\nI am vision,I have 2 special features.\nI can help you do some calulations and you can know information about Engineering collages"
    ]
    
    print(random.choice(responses))

def get_date_time():
    current_time = datetime.now()
    timeofday_greeting = "Good Morning"
    if current_time.hour > 12 and current_time.hour<=17:
        timeofday_greeting = "Good Afternoon"
    elif current_time.hour>=17 and current_time.hour<=22:
        timeofday_greeting = "Good Evening"
    elif current_time.hour>=22:
        timeofday_greeting = "Hi, Thats late"
    return timeofday_greeting


def welcome(name):
    messages=["Nice to meet you",
             "Very delightful to have a conversation with you"]
    return f"{get_date_time()}\n{random.choice(messages)},{name}"     
def bot_details():
    print("1.calculator")
    print("2.colleges")
    try:
        return input("Enter the name to get the details : ")
    except:
        print("unable to provide information.")
        return 0

def calculator_details():
    print("1.calculate an expression")
    print("2. Get current time")
    print("3. End this chat")
    print("-----------------------------------")
    try: 
        return int(input("Enter your choice[1-3] : "))
    except:
        print("Only enter choice from 1 to 3")
        return 0
       


def evaluate_exp():
    expr = input("Enter an expression")
    try:
        print("Result = ",eval(expr))
    except Exception as e:
        print(str(e))


def colleges_list():
    print("This is the list of Engineering collages we are providing you : ")
    print("1. Vishnu Institute of Technology")
    print("2. Shri Vishnu Engineering college")
    print("3. Sagi Ramakrishna Engineering college")
    print("4. Malla Reddy Engineering college")
    print("5. Gudlavalleru Engineering college")
    print("6. To stop conversation.")
    print("-------------------------------------------------")
    global college
    college = int(input("enter your choice[1-6]: "))
    try:
        return college
    except:
        print("Only enter choice from 1 to 6 ")
        return 0
def college_area():
	if college ==1 and more_details==1:
		print("The campus spreads over 100 acres of land.")
	elif college==2 and more_details==1:
		print("The College campus spreads across 100 acres of landscape with a clean climate that provides a congenial atmosphere to pursue higher studies.")
	elif college==3 and more_details==1:
		print("The campus spreads over 30 acres of land.")
	elif college==4 and more_details==1:
		print("The MRCET campus covers 30 acres.")
	elif college==5 and more_details==1:
		print("The campus spreads over 13 acres of land.")
def placements():
	if college==1 and more_details==2:
		print("2018-2019 placements- 676")
	elif college==2 and more_details==2:
		print("placements 2018-2019::634")
	elif college==3 and more_details==2:
		print("placements :: 2018-2019 -656.")
	elif college==4 and more_details==2:
		print("The Placements of Malla Reddy Engineering College for the academic year 2019 – 2020 has yielded 800+ offers for 600 registered students.")
	elif college==5 and more_details==2:
		print("placements:2018-2019:666")
def library():
	if college==1 and more_details==3:
		print("The Library of Vishnu Institute of Technology was built to keep up International Standards, is located in separate block - a new multi-storied building with carpet area of 1878 sq. meters.")
	elif college==2 and more_details==3:
		print("The Library of Shri Vishnu Engineering College for Women was built to keep up International Standards. The air conditioned library has three floors with an area of 1083 Sq.m. and well-protected with security system. Specialized collections of Books, Journals & Non-book materials are available in Engineering & Technology, Basic Sciences, and Management Sciences. It is replete with 54185 volumes of books, 1380 Journal Back Volumes, 4000 CDs, and 250 audio cassettes.")
	elif college==3 and more_details==3:
		print("There is a library available within the campus for the students.The total area of the library is 1209.25 sqm and can accommodate 300 students at a time. The students are also provided with e-journals, newspaper and magazines.")
	elif college==4 and more_details==3:
		print("Malla Reddy College of Engineering and Technology Library follows the open access system, encouraging the user to browse freely in stock area. Standard Text books and books by authors of repute in all fields taught at the college are stocked. The college follows a policy of buying multiples copies of many of these books to make them available to a large number of students.")
	elif college==5 and more_details==3:
		print("central library is available within the campus for students.")
def hostels():
	if college==1 and more_details==4:
		print("In Vit campus Seperate hostels are available for the boys & girls.The college hostels are furnished with all the modern facilities such as:-\n*Reading Room\n Entertainment Zone\n Indoor/Outdoor Games\n*Medical Facilities\n* Many more")
	elif college==2 and more_details==4:
		print("Ideal hostel facility with homely atmosphere is provided within the campus. Mess with a modern kitchen and spacious air-conditioned dining halls are attached to the hostel. Many recreation facilities are also provided.A reading room / T.V. room is provided separately in each block. It will be operated during stipulated hours.Indoor / outdoor games are provided in the hostel. Pictures are screened regularly in the auditorium.")
	elif college==3 and more_details==4:
		print("Seperate hostels are available for both boys & girlsThe hostels are located just opposite the college is a convenient, safe and comfortable place with all necessary amenities for the students.")
	elif college==4 and more_details==4:
		print("Modern, hygienic and eco friendly hostels are available. Separate Hostels for Girls & Boys with Library, computers with Internet, Gym and Yoga facilities available within the campus.")
	elif college==5 and more_details==4:
		print("Seperate hostels are available for both boys & girls within the campus.")
def transport():
	if college==1 and more_details==5:
		print("Govt. rtc buses are available for the students who come from far away places to the college.")
	elif college==2 and more_details==5:
		print("Govt. rtc buses are available for the students who come from far away places to the college.")
	elif college==3 and more_details==5:
		print("Transport facility is available for the students.")
	elif college==4 and more_details==5:
		print("College Buses ply exclusively for students connecting main locations in the city in addition to availability of RTC buses.")
	elif college==5 and more_details==5:
		print("Govt. rtc buses and trains are available for the students to get to the college.")
def options():
	college_details()
	while more_details!=6:
		college_area()
		placements()
		library()
		hostels()
		transport()
		college_details()
def college_details():
	print("To know more about this college..")
	print("enter 1 to know about college area.")
	print("enter 2 to know about placements.")
	print("enter 3 to know about Library.")
	print("enter 4 to know about Hostels.")
	print("enter 5 to know about Transport.")
	print("enter 6 to return to list of colleges")
	global more_details
	more_details = int(input("\nenter your choice[1-6]"))
	try:
		return more_details
	except:
		print("only enter choice from 1 to 6")
		return 0	
		
				
def bot():
    greet_and_introduce()
    name = input("May I know your name \n")
    print(welcome(name))    
    boti=bot_details()
    if(boti=="calculator"):
        choice=calculator_details()
        while choice != 3:
            if choice == 1:
                evaluate_exp()
                print("----------------------------------")
            elif choice ==2:
                print(str(datetime.now()))
            else:
                print("I don't understand that,please enter a valid number")
            choice=calculator_details()
    elif(boti=="colleges"):
        print("Enter the number of colleges. To get the information about Engineering colleges\n")
        print("---------------------------------------")
        choice=colleges_list()
        while choice !=6:
            if choice==1:
                print("Vishnu Institute of Technology college is located in Vishnupur,Bhimavaram\n")
                print("It was established in the year 2008\n")
                print("Founder of the Vishnu Institute of Technology is Sri B.V. Raju\n")
                print("---------------------------------------")
                options()
                print("---------------------------------------")            	
            elif choice==2:
                    print("Shri Vishnu Engineering college is located in Vishnupur,Bhimavarm")
                    print("It was established in the year 2008")
                    print("Founder of the Shri Vishnu Engineering college is Sri B.V. Raju\n")
                    print("---------------------------------------")
                    options()
            elif choice==3:
                    print("Sagi Ramakrishna Engineering college is located in Bhimavaram")
                    print("It was established in the year 1980")
                    print("Fundor of the Sagi Ramakrishna engineering college is Atchutha Rama Raju\n")
                    print("---------------------------------------")
                    options()
            elif choice==4:
                    print("Malla reddy Engineering college is located in Hyderabad")
                    print("It was established in the year 2002")
                    print("Founder of the Malla reddy engineering college is Shri Malla reddy\n")
                    print("---------------------------------------")
                    options()
            elif choice==5:
                    print("Gudlavalleru Engineering college is located in Gudlavalleru")
                    print("It was established in the year 1998")
                    print("Founders of Gudlavalleru engineering college is Sri Adusumilli Aswardha Narayana Murthy, Sri Vallurupalli Venkata Rama Seshadri Rao\n")
                    print("---------------------------------------")
                    options()
            else:
                    print("I don't understand that,please enter a valid number")
                    print("---------------------------------------")
            choice=colleges_list()

    else:
    	print("sorry unable to process your request")         
                                   
bot()
print("thank u..its a pleasure talking with you.. \nHave a great day..! ")
# Out:
# Hi there,its wonderful to see you.
# I am vision,I have 2 special features.
# I can help you do some calulations and you can know information about Engineering collages
# May I know your name
# praneeth
# Good Morning
# Nice to meet you,praneeth
# 1.calculator
# 2.colleges
# Enter the name to get the details : colleges
# Enter the number of colleges. To get the information about Engineering colleges
#
# ---------------------------------------
# This is the list of Engineering collages we are providing you :
# 1. Vishnu Institute of Technology
# 2. Shri Vishnu Engineering college
# 3. Sagi Ramakrishna Engineering college
# 4. Malla Reddy Engineering college
# 5. Gudlavalleru Engineering college
# 6. To stop conversation.
# -------------------------------------------------
# enter your choice[1-6]: 1
# Vishnu Institute of Technology college is located in Vishnupur,Bhimavaram
#
# It was established in the year 2008
#
# Founder of the Vishnu Institute of Technology is Sri B.V. Raju
#
# ...
